# %%
## To update the lib after editing:#import lib#reload(lib)# Generally we just need to load the class and functions:from lib import *
# Out:
# Loading Library functions

# %%
# http://das.sdss.org/spectro/1d_26/0282/1d/spSpec-51658-0282-494.fitspec = Spectra("/Users/ajmendez/Downloads/spSpec-51658-0282-494.fits")
# Out:
# Loaded: 0282-51636-01 [spSpec-51658-0282-494.fits] | RA/DEC: 173.76976, -0.121563 | Wavelength Coverage: [3792.28, 9221.47] Angstroms | Flux Units: 1.0E-17 erg/cm/s/Ang

# %%
help(spec.getSmooth)
# Out:
# Help on method getSmooth in module lib:getSmooth(self, smoothlen, name='boxcar') method of lib.Spectra instance    Returns a smoothed spectra given a smoothing length (smoothlen).    mode = [boxcar], triang, blackman, hamming, hann, bartlett, flattop, parzen, bohman, blackmanharris, nuttall, barthann, ...    see scipy.signal.get_window()

# %%
smooth_spec3 = spec.getSmooth(3)smooth_spec100 = spec.getSmooth(100)
# Out:
# Smoothed: 0282-51636-01 [spSpec-51658-0282-494.fits] | RA/DEC: 173.76976, -0.121563 | Wavelength Coverage: [3792.28, 9221.47] Angstroms | Flux Units: 1.0E-17 erg/cm/s/AngSmoothed: 0282-51636-01 [spSpec-51658-0282-494.fits] | RA/DEC: 173.76976, -0.121563 | Wavelength Coverage: [3792.28, 9221.47] Angstroms | Flux Units: 1.0E-17 erg/cm/s/Ang

# %%
diff_spec = smooth_spec3-smooth_spec100diff_spec.info()diff_spec.plot(xr=[5100,5250],                yr=[-10,10])pysurvey.plot.line(y=0)
# Out:
# Subtracted: 0282-51636-01 [spSpec-51658-0282-494.fits] | RA/DEC: 173.76976, -0.121563 | Wavelength Coverage: [3792.28, 9221.47] Angstroms | Flux Units: 1.0E-17 erg/cm/s/AngSubtracted: 0282-51636-01 [spSpec-51658-0282-494.fits] | RA/DEC: 173.76976, -0.121563 | Wavelength Coverage: [3792.28, 9221.47] Angstroms | Flux Units: 1.0E-17 erg/cm/s/Ang
